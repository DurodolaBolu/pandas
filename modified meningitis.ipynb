# %% [markdown]
# # Filtering Data

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('new_meningitis.csv', index_col='id')
data.loc[(data['gender'] == 'Female') & ((data['age'] <= 30) | (data['state'] == 'Ogun'))]

# Using query method to perform same purpose
data.query("(gender == 'Female' & age < 30) | state == 'Ogun'")
# Out:
#           surname    firstname  middlename  gender                      state  \
# id
# 3          Sanusi       Adaugo    Katerine  Female                       Ogun
# 10         Okorie       Adaugo       Chika  Female                       Osun
# 11      Muhammadu       Adijah    Cathrine  Female                      Niger
# 16       Jesufemi      Fausiat     Tofunmi  Female                        Imo
# 22         Eleojo       Adaugo     Aderemi  Female                     Rivers
# 24        Bayeero       Areoye     Adesina    Male                       Ogun
# 28           Egar         Jane        Sade  Female                      Kwara
# 30            Isa     Caroline    Solabomi  Female                       Yobe
# 33       Igbonubi      Paulina    Rofeeqat  Female                       Kogi
# 36          Akala  Christianah      Nifemi  Female                    Katsina
# 42         Quayum   Alexandria    Beatrice  Female                        Oyo
# ...

# %%
by_gender = data.groupby('gender')
grouped = by_gender['dat']
# Out:
# id
# 1         1986-01-17
# 3         1988-05-01
# 4         1947-05-24
# 6         1968-06-06
# 7         1949-07-19
# 10        1999-10-19
# 11        1998-06-07
# 15        1952-04-07
# 16        2015-06-21
# 19        1980-05-15
# 20        1978-07-21
# 21        1960-05-25
# 22        1997-06-02
# 23        1975-05-27
# 25        1973-10-05
# 27        1946-07-02
# 28        2009-08-20
# 30        2018-04-19
# 33        2015-07-05
# 36        1987-12-26
# 38        1977-06-06
# 39        1944-01-02
# 42        1994-05-17
# 43        1977-09-06
# 44        1995-01-10
# 45        2016-05-06
# 46        2013-12-10
# 48        1980-07-11
# 49        1979-02-15
# 54        1965-02-14
#              ...
# 288373    1966-09-01
# 288374    1961-12-26
# 288377    2016-09-09
# 288378    1955-05-24
# 288379    1947-06-08
# 288386    1966-02-25
# 288387    2013-12-06
# 288388    1955-01-29
# 288389    1993-04-21
# 288390    1970-02-04
# 288391    1992-04-14
# 288392    1944-05-05
# ...
